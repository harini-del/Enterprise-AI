# %%
import nltk

# %%
import pickle

# %%
from nltk.stem import WordNetLemmatizer
import json
lem = WordNetLemmatizer()

# %%
import random
import numpy as np

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

# %%
words =[]
documents= []
classes = []
ignore_words = ['!','?',':',';','.',',','-']

# %%
intents = open('intents.json').read()
images = open('images.json').read()
suggestions = open('suggestions.json').read()

# %%
intents = json.loads(intents)

# %%
images = json.loads(images)

# %%
suggestions = json.loads(suggestions)

# %%
import nltk
nltk.download('punkt')
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w,intent['tag']))
        
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
import nltk
nltk.download('wordnet')
words = [lem.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))
# Out:
# [nltk_data] Error loading wordnet: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))

# %%
training=[]

output_empty = [0]*len(classes)

for doc in documents:
    
    bag =[]
    
    pattern_words = doc[0] # list of tokenized words for each doc
    
    pattern_words = [lem.lemmatize(w.lower()) for w in pattern_words]
    
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] =1
    training.append([bag , output_row])

random.shuffle(training)
training  = np.array(training)
train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# <ipython-input-15-8899f1b6c4f6>:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training  = np.array(training)

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu')) #input layer
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu')) #hidden layer with 64 neurons
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]),activation='softmax')) #output layer number of neurons=intent

sgd = SGD(lr = 0.01, decay = 1e-6, momentum=0.9, nesterov=True) # learning rate = 0.01 
model.compile(loss='categorical_crossentropy', optimizer = sgd, metrics = ['accuracy'])

#fitting and saving the model

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

model.save('chatbot_model.h5', hist)
# Out:
# Epoch 1/200
# 54/54 [==============================] - 0s 3ms/step - loss: 3.8316 - accuracy: 0.0410
# Epoch 2/200
# 54/54 [==============================] - 0s 3ms/step - loss: 3.6649 - accuracy: 0.0672
# Epoch 3/200
# 54/54 [==============================] - 0s 3ms/step - loss: 3.5001 - accuracy: 0.1306
# Epoch 4/200
# 54/54 [==============================] - 0s 3ms/step - loss: 3.1856 - accuracy: 0.1866
# Epoch 5/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.8881 - accuracy: 0.2836
# Epoch 6/200
# 54/54 [==============================] - 0s 2ms/step - loss: 2.6263 - accuracy: 0.3358
# Epoch 7/200
# 54/54 [==============================] - 0s 3ms/step - loss: 2.3349 - accuracy: 0.3955
# Epoch 8/200
# 54/54 [==============================] - 0s 3ms/step - loss: 2.0982 - accuracy: 0.4254
# Epoch 9/200
# 54/54 [==============================] - 0s 3ms/step - loss: 1.9118 - accuracy: 0.4403
# Epoch 10/200
# 54/54 [==============================] - 0s 3ms/step - loss: 1.6817 - accuracy: 0.5224
# Epoch 11/200
# 54/54 [==============================] - 0s 3ms/step - loss: 1.5257 - accuracy: 0.5672
# Epoch 12/200
# 54/54 [==============================] - 0s 3ms/step - loss: 1.3008 - accuracy: 0.6530
# Epoch 13/200
# 54/54 [==============================] - 0s 3ms/step - loss: 1.3768 - accuracy: 0.6119
# Epoch 14/200
# 54/54 [==============================] - 0s 2ms/step - loss: 1.1475 - accuracy: 0.6716
# Epoch 15/200
# 54/54 [==============================] - 0s 3ms/step - loss: 1.0988 - accuracy: 0.6754
# Epoch 16/200
# 54/54 [==============================] - 0s 2ms/step - loss: 1.0185 - accuracy: 0.7015
# Epoch 17/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.9903 - accuracy: 0.6791
# Epoch 18/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.9392 - accuracy: 0.7500
# Epoch 19/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.8131 - accuracy: 0.7388
# Epoch 20/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.8935 - accuracy: 0.7127
# Epoch 21/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.7047 - accuracy: 0.7985
# Epoch 22/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.7361 - accuracy: 0.7836
# Epoch 23/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.7020 - accuracy: 0.7873
# Epoch 24/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6604 - accuracy: 0.8097
# Epoch 25/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6069 - accuracy: 0.8545
# Epoch 26/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5859 - accuracy: 0.8321
# Epoch 27/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5534 - accuracy: 0.8470
# Epoch 28/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.5722 - accuracy: 0.8358
# Epoch 29/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4564 - accuracy: 0.8769
# Epoch 30/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.6022 - accuracy: 0.8134
# Epoch 31/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4877 - accuracy: 0.8582
# Epoch 32/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.5406 - accuracy: 0.8358
# Epoch 33/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4851 - accuracy: 0.8396
# Epoch 34/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.4669 - accuracy: 0.8507
# Epoch 35/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.8545
# Epoch 36/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.8694
# Epoch 37/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4208 - accuracy: 0.8694
# Epoch 38/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.8507
# Epoch 39/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4432 - accuracy: 0.8507
# Epoch 40/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3369 - accuracy: 0.8806
# Epoch 41/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.8881
# Epoch 42/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8619
# Epoch 43/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.8881
# Epoch 44/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3547 - accuracy: 0.8993
# Epoch 45/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3656 - accuracy: 0.8843: 0s - loss: 0.3750 - accuracy: 0.
# Epoch 46/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3595 - accuracy: 0.8694
# Epoch 47/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2676 - accuracy: 0.9254
# Epoch 48/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3052 - accuracy: 0.9030
# Epoch 49/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3530 - accuracy: 0.8843
# Epoch 50/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3291 - accuracy: 0.8843
# Epoch 51/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.4297 - accuracy: 0.8582
# Epoch 52/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.3374 - accuracy: 0.9067
# Epoch 53/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8731
# Epoch 54/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2797 - accuracy: 0.8993
# Epoch 55/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3262 - accuracy: 0.8843
# Epoch 56/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2880 - accuracy: 0.9030
# Epoch 57/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.8955: 0s - loss: 0.3096 - accuracy: 0.90
# Epoch 58/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3190 - accuracy: 0.8806
# Epoch 59/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2869 - accuracy: 0.9142
# Epoch 60/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3031 - accuracy: 0.8881
# Epoch 61/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2491 - accuracy: 0.9179
# Epoch 62/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3040 - accuracy: 0.9104
# Epoch 63/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2136 - accuracy: 0.9254
# Epoch 64/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2886 - accuracy: 0.9030
# Epoch 65/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2906 - accuracy: 0.9142
# Epoch 66/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2835 - accuracy: 0.9030
# Epoch 67/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2989 - accuracy: 0.8918
# Epoch 68/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.9179
# Epoch 69/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2690 - accuracy: 0.9104
# Epoch 70/200
# 54/54 [==============================] - ETA: 0s - loss: 0.3019 - accuracy: 0.90 - 0s 3ms/step - loss: 0.2642 - accuracy: 0.9142
# Epoch 71/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2423 - accuracy: 0.9254
# Epoch 72/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.9142
# Epoch 73/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.3011 - accuracy: 0.9030
# Epoch 74/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2761 - accuracy: 0.9104
# Epoch 75/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2442 - accuracy: 0.9142
# Epoch 76/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2576 - accuracy: 0.9067
# Epoch 77/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2430 - accuracy: 0.9179
# Epoch 78/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2155 - accuracy: 0.9254
# Epoch 79/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1996 - accuracy: 0.9366
# Epoch 80/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2598 - accuracy: 0.9067
# Epoch 81/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2736 - accuracy: 0.9030
# Epoch 82/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2523 - accuracy: 0.9216
# Epoch 83/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1828 - accuracy: 0.9478
# Epoch 84/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2487 - accuracy: 0.9104
# Epoch 85/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2609 - accuracy: 0.9142
# Epoch 86/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2667 - accuracy: 0.9067
# Epoch 87/200
# 54/54 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.94 - 0s 3ms/step - loss: 0.1899 - accuracy: 0.9440
# Epoch 88/200
# 54/54 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.89 - 0s 3ms/step - loss: 0.2682 - accuracy: 0.8955
# Epoch 89/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1900 - accuracy: 0.9366
# Epoch 90/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2167 - accuracy: 0.9328
# Epoch 91/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2053 - accuracy: 0.9328
# Epoch 92/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2343 - accuracy: 0.8993
# Epoch 93/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1572 - accuracy: 0.9552
# Epoch 94/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2506 - accuracy: 0.9104
# Epoch 95/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2010 - accuracy: 0.9403
# Epoch 96/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1875 - accuracy: 0.9142
# Epoch 97/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2419 - accuracy: 0.9142
# Epoch 98/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1908 - accuracy: 0.9440
# Epoch 99/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1452 - accuracy: 0.9515
# Epoch 100/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1913 - accuracy: 0.9478
# Epoch 101/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1584 - accuracy: 0.9552
# Epoch 102/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1883 - accuracy: 0.9515
# Epoch 103/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2208 - accuracy: 0.9179
# Epoch 104/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1998 - accuracy: 0.9403
# Epoch 105/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1895 - accuracy: 0.9254
# Epoch 106/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2350 - accuracy: 0.9216
# Epoch 107/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2409 - accuracy: 0.9179
# Epoch 108/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1729 - accuracy: 0.9440
# Epoch 109/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2301 - accuracy: 0.9142
# Epoch 110/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1462 - accuracy: 0.9515
# Epoch 111/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1889 - accuracy: 0.9291: 0s - loss: 0.1507 - accuracy: 0.
# Epoch 112/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1921 - accuracy: 0.9142
# Epoch 113/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9328
# Epoch 114/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2007 - accuracy: 0.9254
# Epoch 115/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1861 - accuracy: 0.9291
# Epoch 116/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2017 - accuracy: 0.9254
# Epoch 117/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2009 - accuracy: 0.9403
# Epoch 118/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2623 - accuracy: 0.9216
# Epoch 119/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2368 - accuracy: 0.9216
# Epoch 120/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9478
# Epoch 121/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1914 - accuracy: 0.9366
# Epoch 122/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1367 - accuracy: 0.9664
# Epoch 123/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2351 - accuracy: 0.9254
# Epoch 124/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1586 - accuracy: 0.9328
# Epoch 125/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1984 - accuracy: 0.9328
# Epoch 126/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1826 - accuracy: 0.9254
# Epoch 127/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2506 - accuracy: 0.9179
# Epoch 128/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2155 - accuracy: 0.9328
# Epoch 129/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1317 - accuracy: 0.9552
# Epoch 130/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1682 - accuracy: 0.9440
# Epoch 131/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9440
# Epoch 132/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1595 - accuracy: 0.9440
# Epoch 133/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2005 - accuracy: 0.9104
# Epoch 134/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1879 - accuracy: 0.9366
# Epoch 135/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1309 - accuracy: 0.9478
# Epoch 136/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9478
# Epoch 137/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1595 - accuracy: 0.9552
# Epoch 138/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1675 - accuracy: 0.9403
# Epoch 139/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1442 - accuracy: 0.9440
# Epoch 140/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2151 - accuracy: 0.9403
# Epoch 141/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1737 - accuracy: 0.9403
# Epoch 142/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1755 - accuracy: 0.9366
# Epoch 143/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1873 - accuracy: 0.9440
# Epoch 144/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1024 - accuracy: 0.9590
# Epoch 145/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2168 - accuracy: 0.9403
# Epoch 146/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1802 - accuracy: 0.9515
# Epoch 147/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1834 - accuracy: 0.9478
# Epoch 148/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1394 - accuracy: 0.9478: 0s - loss: 0.1343 - accuracy: 0.95
# Epoch 149/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2086 - accuracy: 0.9328
# Epoch 150/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1978 - accuracy: 0.9478
# Epoch 151/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1538 - accuracy: 0.9440
# Epoch 152/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1662 - accuracy: 0.9403
# Epoch 153/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1695 - accuracy: 0.9440
# Epoch 154/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1271 - accuracy: 0.9627
# Epoch 155/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2069 - accuracy: 0.9291
# Epoch 156/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9627
# Epoch 157/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1667 - accuracy: 0.9515
# Epoch 158/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1303 - accuracy: 0.9515
# Epoch 159/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.9627
# Epoch 160/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1587 - accuracy: 0.9478
# Epoch 161/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1497 - accuracy: 0.9515
# Epoch 162/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1523 - accuracy: 0.9403
# Epoch 163/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9664
# Epoch 164/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9590
# Epoch 165/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9440
# Epoch 166/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1745 - accuracy: 0.9403
# Epoch 167/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1758 - accuracy: 0.9403
# Epoch 168/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2159 - accuracy: 0.9440
# Epoch 169/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1521 - accuracy: 0.9515
# Epoch 170/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1965 - accuracy: 0.9291
# Epoch 171/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1467 - accuracy: 0.9515
# Epoch 172/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9291
# Epoch 173/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.1440 - accuracy: 0.9515
# Epoch 174/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2097 - accuracy: 0.9291
# Epoch 175/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.0975 - accuracy: 0.9664
# Epoch 176/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1515 - accuracy: 0.9478
# Epoch 177/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1508 - accuracy: 0.9515
# Epoch 178/200
# 54/54 [==============================] - 0s 5ms/step - loss: 0.1693 - accuracy: 0.9366
# Epoch 179/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1525 - accuracy: 0.9515
# Epoch 180/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2113 - accuracy: 0.9328
# Epoch 181/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1471 - accuracy: 0.9403
# Epoch 182/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1125 - accuracy: 0.9664: 0s - loss: 0.0724 - accuracy: 0.
# Epoch 183/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1930 - accuracy: 0.9478
# Epoch 184/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1788 - accuracy: 0.9328
# Epoch 185/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2286 - accuracy: 0.9254: 0s - loss: 0.2090 - accuracy: 0.92
# Epoch 186/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1766 - accuracy: 0.9440
# Epoch 187/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1630 - accuracy: 0.9403
# Epoch 188/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1815 - accuracy: 0.9627
# Epoch 189/200
# 54/54 [==============================] - 0s 4ms/step - loss: 0.2352 - accuracy: 0.9328
# Epoch 190/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.9701
# Epoch 191/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1476 - accuracy: 0.9440
# Epoch 192/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1666 - accuracy: 0.9440
# Epoch 193/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1318 - accuracy: 0.9478
# Epoch 194/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.9403
# Epoch 195/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9590
# Epoch 196/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1295 - accuracy: 0.9590
# Epoch 197/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9403
# Epoch 198/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9813
# Epoch 199/200
# 54/54 [==============================] - 0s 2ms/step - loss: 0.1726 - accuracy: 0.9403
# Epoch 200/200
# 54/54 [==============================] - 0s 3ms/step - loss: 0.2046 - accuracy: 0.9403

# %%
from keras.models import load_model

# %%
model = load_model('chatbot_model.h5')

# %%
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl','rb'))

classes = pickle.load(open('classes.pkl','rb'))

# %%
def cleanup_sent(sentence):
    sen_words =  nltk.word_tokenize(sentence)
    sen_words = [lem.lemmatize(word.lower()) for word in sen_words]
    return sen_words

# %%
def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sen_words = cleanup_sent(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words) 
    for s in sen_words:
        for i,w in enumerate(words):
            if w == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

# %%
def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    PROB_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>PROB_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

# %%
def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result
def getImage(ints, images_json):
    list_images = images_json['intents']
    tag = ints[0]['intent']
    for i in list_images:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            return result
    return ("-1")
def getSuggest(ints, sugg_json):
    tag = ints[0]['intent']
    list_sugg = sugg_json['intents']
    for i in list_sugg:
        if(i['tag']== tag):
            result = i['responses']
            return result
    return("-1")
def chatbot_response(text):
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    img = getImage(ints, images)
    sugg = getSuggest(ints,suggestions)
    answer=[]
    answer.append(res)
    if img!='-1':
        answer.append(img)
    else:
        answer.append("-1")
    if sugg!='-1':
        answer.append(sugg)
    else:
        answer.append("-1")
    return answer

# %%
import tkinter
from tkinter import *
from PIL import Image,ImageTk

# %%
def fb():
    window = Toplevel(base)
    window.title("Feedback")
    window.geometry("200x200")
    var='0'
    #var.set(0)
    r1 = Radiobutton(window, text='1 Star ', variable=var, value='1', background = "light blue",command=window.destroy,tristatevalue=0)
    r1.pack(side = TOP, ipady = 5) 
    r2 = Radiobutton(window, text='2 Stars', variable=var, value='2',background = "light blue", command=window.destroy,tristatevalue=0)
    r2.pack(side = TOP, ipady = 5) 
    r3 = Radiobutton(window, text='3 Stars', variable=var, value='3', background = "light blue",command=window.destroy,tristatevalue=0)
    r3.pack(side = TOP, ipady = 5) 
    r4 = Radiobutton(window, text='4 Stars', variable=var, value='4', background = "light blue",command=window.destroy,tristatevalue=0)
    r4.pack(side = TOP, ipady = 5) 
    r5= Radiobutton(window, text='5 Stars', variable=var, value='5', background = "light blue",command=window.destroy,tristatevalue=0)
    r5.pack(side = TOP, ipady = 5) 
    ChatLog.config(state = NORMAL)
        
    return var

# %%
def printfb(var):
    ChatLog.insert(END, "Jarvis:Thank you for your feedback!\n\n")
    ChatLog.config(state=DISABLED)
    ChatLog.yview(END)

# %%
global img

def send():
    
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)
    if msg != '':
        ChatLog.config(state = NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 14, 'bold' ))
        
        answer = chatbot_response(msg)
        res=answer[0]
        ChatLog.insert(END, "Jarvis: " + res + '\n\n')
        if answer[1]!='-1':
            ChatLog.insert(END, "Jarvis: ")
            result = answer[1]
            img=Image.open(result)
            img=img.resize((300,300),Image.ANTIALIAS)
            img=ImageTk.PhotoImage(img)
            ChatLog.image=img
            ChatLog.image_create(INSERT, image=img)
        if answer[2]!='-1':
            #for i in answer[2]:
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][0], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][0])) ) 
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][1], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][1])) )
            ChatLog.window_create(ChatLog.index("end"), window = Button(ChatLog, text=answer[2][2], width=50,height=2,bg='white',command=lambda:suggsend(answer[2][2])) )
            
        ChatLog.insert(END, "\n\n")
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)
def suggsend(i):
    ChatLog.config(state = NORMAL)
    ChatLog.config(foreground="#442265", font=("Verdana", 16,'bold'))
    answer = chatbot_response(i)
    res=answer[0]
    ChatLog.insert(END, "Jarvis: " + res + '\n')
    
base = Tk()
base.title("Welcome to Customer Care")
base.geometry("700x500")
base.resizable(width=FALSE, height=FALSE)
    
ChatLog = Text(base, bd=0, bg="#FAF5A8", height="8", width="50", font=("Arial",16,'bold'))
        
ChatLog.config(state =  DISABLED)
    
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set
    
SendButton = Button(base, font=("Comic Sans MS",14,'bold'), text="SEND", width="12", height=5,
                    bd=0, bg="#3cd548", activebackground="#3c9d9b",fg='#ffffff',
                    command=send )
 
    #Create the box to enter message

EntryBox = Text(base, bd=0, bg="#FAF5A8",width="29", height="5", font=("Arial",14))
  
scrollbar.place(x=600,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=599)
EntryBox.place(x=6, y=401, height=70, width=350)
SendButton.place(x=370, y=410, height=50,width=150)
fbButton = Button(base, font=("Verdana",12,'bold'), text="Feedback", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command=lambda:printfb(fb()))

fbButton.place(x=6, y=350, height=40) 
base.mainloop()
